# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/data-analisis-and-science-halloween/blob/main/data_analisis_and_science_halloween.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Lendo o arquivo

# %%
df=pd.read_csv('/content/candy-data.csv')
display(df)
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        WelchÕs Fruit Snacks          0       1        0               0
# 83  WertherÕs Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
# ...

# %%
df.describe()
# Out:
#        chocolate     fruity    caramel  peanutyalmondy     nougat  \
# count  85.000000  85.000000  85.000000       85.000000  85.000000
# mean    0.435294   0.447059   0.164706        0.164706   0.082353
# std     0.498738   0.500140   0.373116        0.373116   0.276533
# min     0.000000   0.000000   0.000000        0.000000   0.000000
# 25%     0.000000   0.000000   0.000000        0.000000   0.000000
# 50%     0.000000   0.000000   0.000000        0.000000   0.000000
# 75%     1.000000   1.000000   0.000000        0.000000   0.000000
# max     1.000000   1.000000   1.000000        1.000000   1.000000
#
#        crispedricewafer       hard        bar   pluribus  sugarpercent  \
# count         85.000000  85.000000  85.000000  85.000000     85.000000
# mean           0.082353   0.176471   0.247059   0.517647      0.478647
# std            0.276533   0.383482   0.433861   0.502654      0.282778
# min            0.000000   0.000000   0.000000   0.000000      0.011000
# ...

# %%
chocolate=df.loc[:,['competitorname', 'chocolate']]
display(chocolate)
# Out:
#                 competitorname  chocolate
# 0                    100 Grand          1
# 1                 3 Musketeers          1
# 2                     One dime          0
# 3                  One quarter          0
# 4                    Air Heads          0
# ..                         ...        ...
# 80                   Twizzlers          0
# 81                    Warheads          0
# 82        WelchÕs Fruit Snacks          0
# 83  WertherÕs Original Caramel          0
# 84                    Whoppers          1
#
# [85 rows x 2 columns]

# %%
media=chocolate.mean()
print(media)
# Out:
# chocolate    0.435294
# dtype: float64
# <ipython-input-22-ce84624aac87>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   media=chocolate.mean()

# %%
chocolate1=df.loc[(df['chocolate'])==1]
chocolate_marca_1=chocolate1[['competitorname' , 'chocolate']]
display(chocolate_marca_1)
# Out:
#                  competitorname  chocolate
# 0                     100 Grand          1
# 1                  3 Musketeers          1
# 5                    Almond Joy          1
# 6                     Baby Ruth          1
# 10              Charleston Chew          1
# 22             HersheyÕs Kisses          1
# 23            HersheyÕs Krackel          1
# 24     HersheyÕs Milk Chocolate          1
# 25       HersheyÕs Special Dark          1
# 27                 Junior Mints          1
# 28                      Kit Kat          1
# 32          Peanut butter M&MÕs          1
# 33                        M&MÕs          1
# 35                    Milk Duds          1
# 36                    Milky Way          1
# 37           Milky Way Midnight          1
# 38     Milky Way Simply Caramel          1
# 39                       Mounds          1
# 40                  Mr Good Bar          1
# 42          Nestle Butterfinger          1
# 43                Nestle Crunch          1
# ...

# %%
chocolate2=df.loc[(df['chocolate'])==0]
chocolate_marca_2=chocolate2[['competitorname' , 'chocolate']]
display(chocolate_marca_2)
# Out:
#                  competitorname  chocolate
# 2                      One dime          0
# 3                   One quarter          0
# 4                     Air Heads          0
# 7            Boston Baked Beans          0
# 8                    Candy Corn          0
# 9            Caramel Apple Pops          0
# 11   Chewey Lemonhead Fruit Mix          0
# 12                     Chiclets          0
# 13                         Dots          0
# 14                     Dum Dums          0
# 15                  Fruit Chews          0
# 16                      Fun Dip          0
# 17                   Gobstopper          0
# 18            Haribo Gold Bears          0
# 19            Haribo Happy Cola          0
# 20            Haribo Sour Bears          0
# 21           Haribo Twin Snakes          0
# 26                   Jawbusters          0
# 29                  Laffy Taffy          0
# 30                    Lemonhead          0
# 31  Lifesavers big ring gummies          0
# ...

# %%
frutas = df.loc[(df['fruity'])==1]
display(frutas)
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 4                     Air Heads          0       1        0               0
# 9            Caramel Apple Pops          0       1        1               0
# 11   Chewey Lemonhead Fruit Mix          0       1        0               0
# 12                     Chiclets          0       1        0               0
# 13                         Dots          0       1        0               0
# 14                     Dum Dums          0       1        0               0
# 15                  Fruit Chews          0       1        0               0
# 16                      Fun Dip          0       1        0               0
# 17                   Gobstopper          0       1        0               0
# 18            Haribo Gold Bears          0       1        0               0
# 20            Haribo Sour Bears          0       1        0               0
# ...

# %%
df_frutas = frutas[['competitorname', 'fruity']]
display(df_frutas)
# Out:
#                  competitorname  fruity
# 4                     Air Heads       1
# 9            Caramel Apple Pops       1
# 11   Chewey Lemonhead Fruit Mix       1
# 12                     Chiclets       1
# 13                         Dots       1
# 14                     Dum Dums       1
# 15                  Fruit Chews       1
# 16                      Fun Dip       1
# 17                   Gobstopper       1
# 18            Haribo Gold Bears       1
# 20            Haribo Sour Bears       1
# 21           Haribo Twin Snakes       1
# 26                   Jawbusters       1
# 29                  Laffy Taffy       1
# 30                    Lemonhead       1
# 31  Lifesavers big ring gummies       1
# 34                   Mike & Ike       1
# 41                        Nerds       1
# 44                    Nik L Nip       1
# 45                  Now & Later       1
# 49                    Pop Rocks       1
# 50                    Red vines       1
# ...

# %%
df_chocolate_caramelo = df[['competitorname','chocolate', 'caramel']]
display(df_chocolate_caramelo)
# Out:
#                 competitorname  chocolate  caramel
# 0                    100 Grand          1        1
# 1                 3 Musketeers          1        0
# 2                     One dime          0        0
# 3                  One quarter          0        0
# 4                    Air Heads          0        0
# ..                         ...        ...      ...
# 80                   Twizzlers          0        0
# 81                    Warheads          0        0
# 82        WelchÕs Fruit Snacks          0        0
# 83  WertherÕs Original Caramel          0        1
# 84                    Whoppers          1        0
#
# [85 rows x 3 columns]

# %%
caramelo_chocolate_1=df_chocolate_caramelo.loc[(df_chocolate_caramelo['caramel'])==1]
display(caramelo_chocolate_1)
# Out:
#                 competitorname  chocolate  caramel
# 0                    100 Grand          1        1
# 6                    Baby Ruth          1        1
# 9           Caramel Apple Pops          0        1
# 35                   Milk Duds          1        1
# 36                   Milky Way          1        1
# 37          Milky Way Midnight          1        1
# 38    Milky Way Simply Caramel          1        1
# 56                        Rolo          1        1
# 64                    Snickers          1        1
# 65            Snickers Crisper          1        1
# 70                Sugar Babies          0        1
# 71                 Sugar Daddy          0        1
# 79                        Twix          1        1
# 83  WertherÕs Original Caramel          0        1

# %%
caramelo_chocolate_marca_1 = caramelo_chocolate_1.loc[(caramelo_chocolate_1['chocolate']==1)]
display(caramelo_chocolate_marca_1)
# Out:
#               competitorname  chocolate  caramel
# 0                  100 Grand          1        1
# 6                  Baby Ruth          1        1
# 35                 Milk Duds          1        1
# 36                 Milky Way          1        1
# 37        Milky Way Midnight          1        1
# 38  Milky Way Simply Caramel          1        1
# 56                      Rolo          1        1
# 64                  Snickers          1        1
# 65          Snickers Crisper          1        1
# 79                      Twix          1        1

# %%
barra = df[['competitorname', 'bar']]
display(barra)
# Out:
#                 competitorname  bar
# 0                    100 Grand    1
# 1                 3 Musketeers    1
# 2                     One dime    0
# 3                  One quarter    0
# 4                    Air Heads    0
# ..                         ...  ...
# 80                   Twizzlers    0
# 81                    Warheads    0
# 82        WelchÕs Fruit Snacks    0
# 83  WertherÕs Original Caramel    0
# 84                    Whoppers    0
#
# [85 rows x 2 columns]

# %%
barra_1 = barra.loc[(barra['bar'])==1]
display(barra_1)
# Out:
#               competitorname  bar
# 0                  100 Grand    1
# 1               3 Musketeers    1
# 5                 Almond Joy    1
# 6                  Baby Ruth    1
# 10           Charleston Chew    1
# 23         HersheyÕs Krackel    1
# 24  HersheyÕs Milk Chocolate    1
# 25    HersheyÕs Special Dark    1
# 28                   Kit Kat    1
# 36                 Milky Way    1
# 37        Milky Way Midnight    1
# 38  Milky Way Simply Caramel    1
# 39                    Mounds    1
# 40               Mr Good Bar    1
# 42       Nestle Butterfinger    1
# 43             Nestle Crunch    1
# 46                    Payday    1
# 64                  Snickers    1
# 65          Snickers Crisper    1
# 77   Tootsie Roll Snack Bars    1
# 79                      Twix    1

# %%
chocolate_amendoin = df[['competitorname', 'chocolate', 'peanutyalmondy']]
display(chocolate_amendoin)
# Out:
#                 competitorname  chocolate  peanutyalmondy
# 0                    100 Grand          1               0
# 1                 3 Musketeers          1               0
# 2                     One dime          0               0
# 3                  One quarter          0               0
# 4                    Air Heads          0               0
# ..                         ...        ...             ...
# 80                   Twizzlers          0               0
# 81                    Warheads          0               0
# 82        WelchÕs Fruit Snacks          0               0
# 83  WertherÕs Original Caramel          0               0
# 84                    Whoppers          1               0
#
# [85 rows x 3 columns]

# %%
amendoin_1 = chocolate_amendoin.loc[(chocolate_amendoin['peanutyalmondy'])==1]
display(amendoin_1)
# Out:
#                  competitorname  chocolate  peanutyalmondy
# 5                    Almond Joy          1               1
# 6                     Baby Ruth          1               1
# 7            Boston Baked Beans          0               1
# 32          Peanut butter M&MÕs          1               1
# 40                  Mr Good Bar          1               1
# 42          Nestle Butterfinger          1               1
# 46                       Payday          0               1
# 47                  Peanut M&Ms          1               1
# 51           ReeseÕs Miniatures          1               1
# 52    ReeseÕs Peanut Butter cup          1               1
# 53               ReeseÕs pieces          1               1
# 54  ReeseÕs stuffed with pieces          1               1
# 64                     Snickers          1               1
# 65             Snickers Crisper          1               1

# %%
chocolate_amendoin_1=amendoin_1.loc[(amendoin_1['chocolate'])==1]
display(chocolate_amendoin_1)
# Out:
#                  competitorname  chocolate  peanutyalmondy
# 5                    Almond Joy          1               1
# 6                     Baby Ruth          1               1
# 32          Peanut butter M&MÕs          1               1
# 40                  Mr Good Bar          1               1
# 42          Nestle Butterfinger          1               1
# 47                  Peanut M&Ms          1               1
# 51           ReeseÕs Miniatures          1               1
# 52    ReeseÕs Peanut Butter cup          1               1
# 53               ReeseÕs pieces          1               1
# 54  ReeseÕs stuffed with pieces          1               1
# 64                     Snickers          1               1
# 65             Snickers Crisper          1               1
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
barra_amendoin = df[['competitorname', 'bar', 'peanutyalmondy']]
display(barra_amendoin)
# Out:
#                 competitorname  bar  peanutyalmondy
# 0                    100 Grand    1               0
# 1                 3 Musketeers    1               0
# 2                     One dime    0               0
# 3                  One quarter    0               0
# 4                    Air Heads    0               0
# ..                         ...  ...             ...
# 80                   Twizzlers    0               0
# 81                    Warheads    0               0
# 82        WelchÕs Fruit Snacks    0               0
# 83  WertherÕs Original Caramel    0               0
# 84                    Whoppers    0               0
#
# [85 rows x 3 columns]

# %%
barra_amendoin_1 = barra_amendoin.loc[(barra_amendoin['bar'])==1]
display(barra_amendoin_1)
# Out:
#               competitorname  bar  peanutyalmondy
# 0                  100 Grand    1               0
# 1               3 Musketeers    1               0
# 5                 Almond Joy    1               1
# 6                  Baby Ruth    1               1
# 10           Charleston Chew    1               0
# 23         HersheyÕs Krackel    1               0
# 24  HersheyÕs Milk Chocolate    1               0
# 25    HersheyÕs Special Dark    1               0
# 28                   Kit Kat    1               0
# 36                 Milky Way    1               0
# 37        Milky Way Midnight    1               0
# 38  Milky Way Simply Caramel    1               0
# 39                    Mounds    1               0
# 40               Mr Good Bar    1               1
# 42       Nestle Butterfinger    1               1
# 43             Nestle Crunch    1               0
# 46                    Payday    1               1
# 64                  Snickers    1               1
# ...

# %%
barra_amendoin_marca_1 = barra_amendoin_1.loc[(barra_amendoin_1['peanutyalmondy'])==1]
display(barra_amendoin_marca_1)
# Out:
#          competitorname  bar  peanutyalmondy
# 5            Almond Joy    1               1
# 6             Baby Ruth    1               1
# 40          Mr Good Bar    1               1
# 42  Nestle Butterfinger    1               1
# 46               Payday    1               1
# 64             Snickers    1               1
# 65     Snickers Crisper    1               1
